# %%
# Descarga de datos de Pensiones CL
# Autor: Ian Meza
# 8 de Octubre del 2021

# El término Gecko significa un motor de navegador web integrado en el navegador Mozilla Firefox. 
# El controlador Gecko actúa como un proxy entre los clientes habilitados para el controlador web 
#(Eclipse, Netbeans, etc.) y el navegador Mozilla Firefox. En resumen, el controlador Gecko actúa 
# como un enlace entre las pruebas del controlador web Selenium y el navegador Mozilla Firefox.

# Antes de Selenium 3, el navegador Mozilla Firefox era el navegador predeterminado para Selenium. 
# Después de Selenium 3, los probadores deben inicializar el script para usar Firefox usando GeckoDriver 
# explícitamente. Selenium usa el protocolo W3C Webdriver para enviar solicitudes a GeckoDriver, que las 
# traduce a un protocolo llamado Marionette. Firefox comprenderá los comandos transmitidos en forma de 
# protocolo Marionette y los ejecutará.

# https://www.guru99.com/gecko-marionette-driver-selenium.html
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.firefox.firefox_profile import FirefoxProfile
from selenium.webdriver.firefox.options import Options
import http.client, urllib.request, urllib.parse, urllib.error, base64
import shutil
import datetime
from selenium.webdriver.support.ui import Select
import time
import pandas as pd
import os
import glob

# %%
def getDriver():
    
    #download_folder = "C:/Users/Ian/Documents/GitHub/delitos_chile/Poder Judicial/Descargas"
    
    # Options se ha importado desde Selenium
    
    options = Options()
    options.set_preference("browser.download.dir", r"C:\Users\Ian\Documents\GitHub\delitos_chile\Poder Judicial\Descargas")
    #options.set_preference("browser.download.folderList", 2)
    options.set_preference("browser.download.manager.showWhenStarting", False)
    options.set_preference("browser.helperApps.neverAsk.saveToDisk", "text/csv") #, "application/json")
    
    #browser = webdriver.WebDriver(firefox_profile=profile)
    #driver = webdriver.WebDriver(firefox_profile=profile)
    driver = webdriver.Firefox(options=options)
    driver.set_page_load_timeout("60")
    driver.get("https://www.spensiones.cl/apps/centroEstadisticas/paginaCuadrosCCEE.php?menu=sci&menuN1=afil&menuN2=tipfon")
    return driver

# %%
driver = getDriver()

# %%
meses = driver.find_elements_by_tag_name('select')
botones = driver.find_elements_by_tag_name('img')
texto = driver.find_elements_by_tag_name('td')

# %%
k = 1
l = 1
n_arch = 0
tam_textos = len(texto)
recorrido_nombres = range(0,tam_textos,4)
informes = []
for x in recorrido_nombres:
    array = texto[x].text
    informes.append(array)
informes

for i in range(1,len(informes)):
    t = meses[i]
    fecha = t.text
    mes_list = (fecha.rstrip().split('\n'))
    s1 = Select(t)
    for j in mes_list:
        s1.select_by_visible_text(j)
        btndesc = botones[k]
        btndesc.click()
        time.sleep(3)
        list_of_files = glob.glob("C:/Users/Ian/Downloads/*.xls") # * means all if need specific format then *.csv
        latest_file = max(list_of_files, key=os.path.getctime)
        src=latest_file.replace('\\', "/")
        j = j.replace('/', "-")
        x = informes[l][0:1]
        des="C:/Users/Ian/Documents/GitHub/Data_Pensiones/Descargas/Total Pensionados_"+x+"_"+j+".xls"
        os.replace(src,des)
        time.sleep(3)
        
        print(str(n_arch)+".-"+informes[l]+"_"+j)
        n_arch=n_arch+1
    l = l+1
    k = k+1
# Out:
# 0.-2. Número Total de Afiliados Pensionados por Vejez según Sexo y edad_
-3. Número Total de Afiliados Pensionados por Vejez según Tipo, sexo y mes de solicitud de pensión_2016-03
# 276.-3. Número Total de Afiliados Pensionados por Vejez según Tipo, sexo y mes de solicitud de pensión_2016-02

# %%
len(informes)
# Out:
# 59

# %%
tam_textos = len(texto)
recorrido_nombres = range(0,tam_textos,4)
informes = []
for x in recorrido_nombres:
    array = texto[x].text
    informes.append(array)
informes
# Out:
# ['1. Número, monto promedio de las pensiones autofinanciadas en U.F. y monto promedio de las pensiones totales (autofinanciadas más aporte previsional solidario) en U.F. de las pensiones por vejez pagadas en el mes, según años cotizados y sexo',
#  '2. Número, monto promedio de las pensiones autofinanciadas en U.F. y monto promedio de las pensiones totales (autofinanciadas más aporte previsional solidario) en U.F. de las pensiones por vejez pagadas en el mes, según años cotizados y sexo en retiro programado',
#  '3. Número, monto promedio de las pensiones autofinanciadas en U.F. y monto promedio de las pensiones totales (autofinanciadas más aporte previsional solidario) en U.F. de las pensiones por vejez pagadas en el mes, según años cotizados y sexo en renta temporal',
#  '4. Número, monto promedio de las pensiones autofinanciadas en U.F. y monto promedio de las pensiones totales (autofinanciadas más aporte previsional solidario) en U.F. de las pensiones por vejez pagadas en el mes, según años cotizados y sexo en renta vitalicia',
#  '5. Número y monto promedio, en u.f., de las pensiones pagadas en el mes por modalidad, según tipo de pensión',
#  '6. Número y monto promedio, en u.f., de pensiones pagadas en el mes por modalidad, según sexo del causante y tipo de pensión',
#  '7. Número y monto promedio, en u.f., de pensiones de vejez edad, pagadas en el mes por modalidad, según sexo del causante y AFP',
#  '8. Número y monto promedio, en u.f., de pensiones de vejez anticipada, pagadas en el mes por modalidad, según sexo del causante y AFP',
#  '9. Número y monto promedio, en u.f., de pensiones de invalidez total, pagadas en el mes por modalidad, según sexo del causante y AFP',
#  '10. Número y monto promedio, en u.f., de pensiones de invalidez parcial, pagadas en el mes por modalidad, según sexo del causante y AFP',
#  '11. Número y monto promedio, en U.F., de pensiones de invalidez definitiva total segundo dictamen, pagadas en el mes por modalidad, según sexo del causante y AFP',
#  '12. Número y monto promedio, en U.F., de pensiones de invalidez definitiva total único dictamen, pagadas en el mes por modalidad, según sexo del causante y AFP',
#  '13. Número y monto promedio, en U.F., de pensiones de invalidez definitiva total previos, pagadas en el mes por modalidad, según sexo del causante y AFP',
#  '14. Número y monto promedio, en U.F., de pensiones de viudez, pagadas en el mes por modalidad, según sexo del causante y AFP',
#  '15. Número y monto promedio, en U.F., de pensiones de orfandad, pagadas en el mes por modalidad, según sexo del causante y AFP',
#  '16. Número y monto promedio, en U.F., de pensiones de madre de hijo de filiación no matrimonial, pagadas en el mes por modalidad, según sexo del causante y AFP',
#  '17. Número y monto promedio, en U.F., de pensiones de padres del causante, pagadas en el mes por modalidad, según sexo del causante y AFP',
#  '18. Número total de pensiones de vejez, pagadas en el mes, distribuidas según modalidad, sexo y tramo de pensiones, en U.F.',
#  '19. Número total de pensiones de invalidez, pagadas en el mes, según modalidad, sexo del causante y tramos de pensiones, en U.F.',
#  '20. Número total de pensiones de viudez pagadas en el mes, según modalidad, tipo de causante y tramos de pensiones, en U.F.',
#  '21. Número total de pensiones de orfandad pagadas en el mes, según modalidad, tipo del causante y tramos de pensiones, en U.F.',
#  '22. Número total de pensiones de madre de hijo de filiacion no matrimonial pagadas en el mes, según modalidad, tipo de causante y tramos de pensiones, en U.F.',
#  '23. Número y monto promedio, en U.F., de pensiones de padre de hijo de filiación no matrimonial, pagadas en el mes por modalidad, según sexo del causante y AFP',
#  '24. Número total de pensiones de padre de hijo de filiación no matrimonial pagadas en el mes, según modalidad, tipo de causante y tramos de pensiones, en U.F.',
#  '25. Número total de pensiones de padres del causante pagadas en el mes, según modalidad, tipo de causante y tramos de pensiones, en U.F.',
#  '26. Número total y monto promedio, en U.F. de pensiones transitorias de invalidez pagadas en el mes, según sexo del afiliado y tipo de invalidez',
#  '27. Número total y monto promedio, en U.F. de pensiones transitorias de invalidez pagadas en el mes, según a.f.p. y tipo de invalidez',
#  '28. Número y monto total en U.F., de pensiones pagadas en el mes en la modalidad retiros programados, según tipo de pensión, sexo y tipo de fondo',
#  '29. Número y monto total, en U.F., de pensiones pagadas en el mes en la modalidad retiros programados, según tipo de pensión, a.f.p. y tipo de fondo',
#  '30. Número y monto total en U.F., de pensiones pagadas en el mes en la modalidad renta temporal, según tipo de pensión, sexo y tipo de fondo',
#  '31. Número y monto total, en U.F., de pensiones pagadas en el mes en la modalidad renta temporal, según tipo de pensión, a.f.p. y tipo de fondo',
#  '32. Número total y monto promedio, en U.F., de pensiones pagadas en el mes en la modalidad retiro programado, según tipo de ajuste, sexo del causante y tipo de pensión',
#  '33. Número total y monto promedio, en U.F., de pensiones pagadas en el mes incrementadas a la mínima, según a.f.p., sexo del causante y tipo de pensión',
#  '34. Número total y monto promedio, en U.F., de pensiones pagadas en el mes disminuídas en su monto, según a.f.p., sexo del causante y tipo de pensión',
#  '35. Número total y monto promedio, en U.F., de pensiones pagadas en el mes con garantía estatal, según a.f.p., sexo del causante y tipo de pensión',
#  '36. Número total y monto promedio, en U.F., de pensiones pagadas en el mes de acuerdo al monto, según a.f.p., sexo del causante y tipo de pensión',
#  '37. Número total y monto promedio, en U.F., de pensiones pagadas en el mes con aporte previsional solidario, según AFP, sexo del causante y tipo de pensión.',
#  '38. Número y monto promedio, en U.F., de pensiones pagadas en el mes por modalidad cubiertas por el seguro, según forma de financiamiento, sexo del causante y tipo de pensión',
#  '39. Número y monto promedio, en U.F., de pensiones pagadas en el mes por modalidad cubiertas por el seguro con garantía estatal por quiebra, según AFP, sexo del causante y tipo de pensión',
#  '40. Número y monto promedio, en U.F., de pensiones pagadas en el mes por modalidad cubiertas por el seguro con garantía estatal sin quiebra, según AFP, sexo del causante y tipo de pensión',
#  '41. Número y monto promedio, en U.F., de pensiones pagadas en el mes por modalidad cubiertas por el seguro por quiebra con derecho a garantía estatal por pensión mínima, según AFP, sexo del causante y tipo de pensión',
#  '42. Número y monto promedio, en U.F., de pensiones pagadas en el mes por modalidad cubiertas por el seguro por quiebra sin derecho a garantía estatal por pensión mínima, según AFP, sexo del causante y tipo de pensión',
#  '43. Número y monto promedio, en U.F., de pensiones pagadas en el mes por modalidad cubiertas por el seguro con garantía estatal por pensión mínima, según AFP, sexo del causante y tipo de pensión',
#  '44. Número y monto promedio, en U.F., de pensiones pagadas en el mes por modalidad cubiertas por el seguro sin garantía estatal, según AFP, sexo del causante y tipo de pensión',
#  '45. Número total y monto promedio, en U.F., de pensiones pagadas en el mes, según región y tipo de pensión',
#  '46. Número total y monto promedio, en U.F., de pensiones pagadas en el mes por vejez edad, según región y AFP',
#  '47. Número total y monto promedio, en U.F., de pensiones pagadas en el mes por vejez anticipada, según región y AFP',
#  '48. Número total y monto promedio, en U.F., de pensiones pagadas en el mes por invalidez parcial, según región y AFP',
#  '49. Número total y monto promedio, en U.F., de pensiones pagadas en el mes por invalidez total, según región y AFP',
#  '50. Número total y monto promedio, en U.F., de pensiones pagadas en el mes por viudez, según región y AFP',
#  '51. Número total y monto promedio, en U.F., de pensiones pagadas en el mes por orfandad, según región y AFP',
#  '52. Número total y monto promedio, en U.F., de pensiones pagadas en el mes por madre de hijo de filiación no matrimonial, según región y AFP',
#  '53. Número total y monto promedio, en U.F., de pensiones pagadas en el mes por padre de hijo de filiación no matrimonial, según región y AFP',
#  '54. Número total y monto promedio, en U.F., de pensiones pagadas en el mes por padres del causante, según región y AFP',
#  '55. Número total y monto promedio, en U.F., de pensiones adicionales pagadas en el mes, según a.f.p. y tipo de pensión',
#  '56. Número de pensiones, por tipo y Compañia de Seguros',
#  '57. Monto promedio en U.F., por tipo y Compañia de Seguros',
#  '58. Número y monto promedio, en U.F., de pensiones pagadas en el mes y acumulada, en la modalidad renta vitalicia inmediata con retiro programado, según sexo del causante y tipo de pensión.',
#  '59. Número de pensionados según edad y sexo del pensionado y tipo de pensión pagada']

# %%
#### <------- ERROR EN APV POR TIPO DE FONDO -------->
#### Cotizantes del sistema de reparto no tiene select boxes

k = 4
l = 4
n_arch = 0
tam_textos = len(texto)
recorrido_nombres = range(0,tam_textos,4)
informes = []
for x in recorrido_nombres:
    array = texto[x].text
    informes.append(array)
informes

for i in range(4,14):
    t = meses[i]
    fecha = t.text
    mes_list = (fecha.rstrip().split('\n'))
    s1 = Select(t)
    for j in mes_list:
        s1.select_by_visible_text(j)
        btndesc = botones[k]
        btndesc.click()
        time.sleep(3)
        list_of_files = glob.glob("C:/Users/Ian/Downloads/*.xls") # * means all if need specific format then *.csv
        latest_file = max(list_of_files, key=os.path.getctime)
        src=latest_file.replace('\\', "/")
        j = j.replace('/', "-")
        des="C:/Users/Ian/Documents/GitHub/Data_Pensiones/Descargas/"+informes[l]+"_"+j+".xls"
        os.replace(src,des)
        time.sleep(3)
        
        print(str(n_arch)+".-"+informes[l]+"_"+j)
        n_arch=n_arch+1
    l = l+1
    k = k+1
# Out:
# 0.-5. Número total de ahorrantes con cotizaciones voluntarias según tramos de saldo y tramos de edad_2021-06
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-2edafc7692dd> in <module>
#      19         btndesc = botones[k]
#      20         btndesc.click()
# ---> 21         time.sleep(3)
#      22         list_of_files = glob.glob("C:/Users/Ian/Downloads/*.xls") # * means all if need specific format then *.csv
#      23         latest_file = max(list_of_files, key=os.path.getctime)
#
# KeyboardInterrupt:

# %%
#####Reposicion de descargas#####

l=3
k=3

tam_textos = len(texto)
recorrido_nombres = range(0,tam_textos,4)
informes = []
for x in recorrido_nombres:
    array = texto[x].text
    informes.append(array)
informes

#i=2
#j=2
i = meses[3]
fecha = i.text
mes_list = (fecha.rstrip().split('\n'))
s1 = Select(i)
for j in mes_list:
    s1.select_by_visible_text(j)
    btndesc = botones[k]
    btndesc.click()
    time.sleep(3)
    list_of_files = glob.glob("C:/Users/Ian/Downloads/*.xls") # * means all if need specific format then *.csv
    latest_file = max(list_of_files, key=os.path.getctime)
    src=latest_file.replace('\\', "/")
    j = j.replace('/', "-")
    #informes[l] = informes[l].replace('/', "-")
    des="C:/Users/Ian/Documents/GitHub/Data_Pensiones/Descargas/"+informes[l]+"_"+j+".xls"
    os.replace(src,des)
    time.sleep(3)
    print(informes[l]+"_"+j)
    l = l+1
    k = k+1
# Out:
# 4. Número de ahorrantes en cada Fondo y saldo total por cotización voluntaria según, tipo, sexo y AFP (por Fondo)_2021-06
# 5. Número total de ahorrantes con cotizaciones voluntarias según tramos de saldo y tramos de edad_2021-03
# 6. Número total de ahorrantes hombres con cotizaciones voluntarias según tramos de saldo y tramos de edad_2020-12
# 7. Número total de ahorrantes mujeres con cotizaciones voluntarias según tramos de saldo y tramos de edad_2020-09
# 8. Número de ahorrantes en cada Fondo según saldo por depósitos convenidos y edad (por Fondo)_2020-06
# 9. Número de ahorrantes en cada Fondo y saldo total por depósitos convenidos según y edad y AFP (por Fondo)_2020-03
# 10. Número de ahorrantes en cada Fondo según saldo por depósitos convenidos, tipo y sexo (por Fondo)_2019-12
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-0131f71350fb> in <module>
#      21     s1.select_by_visible_text(j)
#      22     btndesc = botones[k]
# ---> 23     btndesc.click()
#      24     time.sleep(3)
#      25     list_of_files = glob.glob("C:/Users/Ian/Downloads/*.xls") # * means all if need specific format then *.csv
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~\anaconda3\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      77             )
#      78         else:
# ---> 79             return self.request_encode_body(
#      80                 method, url, fields=fields, headers=headers, **urlopen_kw
#      81             )
#
# ~\anaconda3\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     169         extra_kw.update(urlopen_kw)
#     170
# --> 171         return self.urlopen(method, url, **extra_kw)
#
# ~\anaconda3\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     334             response = conn.urlopen(method, url, **kw)
#     335         else:
# --> 336             response = conn.urlopen(method, u.request_uri, **kw)
#     337
#     338         redirect_location = redirect and response.get_redirect_location()
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
list_of_files = glob.glob("C:/Users/Ian/Downloads/*.xls") # * means all if need specific format then *.csv

latest_file = max(list_of_files, key=os.path.getctime)
#print(latest_file)
src=latest_file.replace('\\', "/")
j = j.replace('/', "-")


des="C:/Users/Ian/Documents/GitHub/Data_Pensiones/Descargas/"+informes[l]+"_"+j+".xls"
print(des)
#os.replace(src,des)

# %%
fecha = i.text
mes_list = (fecha.rstrip().split('\n'))
mes_list[225]
# Out:
# '2002/10'

# %%
print(mes_list)
# Out:
# ['2021/08', '2021/07', '2021/06', '2021/05', '2021/04', '2021/03', '2021/02', '2021/01', '2020/12', '2020/11', '2020/10', '2020/09', '2020/08', '2020/07', '2020/06', '2020/05', '2020/04', '2020/03', '2020/02', '2020/01', '2019/12', '2019/11', '2019/10', '2019/09', '2019/08', '2019/07', '2019/06', '2019/05', '2019/04', '2019/03', '2019/02', '2019/01', '2018/12', '2018/11', '2018/10', '2018/09', '2018/08', '2018/07', '2018/06', '2018/05', '2018/04', '2018/03', '2018/02', '2018/01', '2017/12', '2017/11', '2017/10', '2017/09', '2017/08', '2017/07', '2017/06', '2017/05', '2017/04', '2017/03', '2017/02', '2017/01', '2016/12', '2016/11', '2016/10', '2016/09', '2016/08', '2016/07', '2016/06', '2016/05', '2016/04', '2016/03', '2016/02', '2016/01', '2015/12', '2015/11', '2015/10', '2015/09', '2015/08', '2015/07', '2015/06', '2015/05', '2015/04', '2015/03', '2015/02', '2015/01', '2014/12', '2014/11', '2014/10', '2014/09', '2014/08', '2014/07', '2014/06', '2014/05', '2014/04', '2014/03', '2014/02', '2014/01', '2013/12', '2013/11', '2013/10', '2013/09', '2013/08', '2013/07', '2013/06', '2013/05', '2013/04', '2013/03', '2013/02', '2013/01', '2012/12', '2012/11', '2012/10', '2012/09', '2012/08', '2012/07', '2012/06', '2012/05', '2012/04', '2012/03', '2012/02', '2012/01', '2011/12', '2011/11', '2011/10', '2011/09', '2011/08', '2011/07', '2011/06', '2011/05', '2011/04', '2011/03', '2011/02', '2011/01', '2010/12', '2010/11', '2010/10', '2010/09', '2010/08', '2010/07', '2010/06', '2010/05', '2010/04', '2010/03', '2010/02', '2010/01', '2009/12', '2009/11', '2009/10', '2009/09', '2009/08', '2009/07', '2009/06', '2009/05', '2009/04', '2009/03', '2009/02', '2009/01', '2008/12', '2008/11', '2008/10', '2008/09', '2008/08', '2008/07', '2008/06', '2008/05', '2008/04', '2008/03', '2008/02', '2008/01', '2007/12', '2007/11', '2007/10', '2007/09', '2007/08', '2007/07', '2007/06', '2007/05', '2007/04', '2007/03', '2007/02', '2007/01', '2006/12', '2006/11', '2006/10', '2006/09', '2006/08', '2006/07', '2006/06', '2006/05', '2006/04', '2006/03', '2006/02', '2006/01', '2005/12', '2005/11', '2005/10', '2005/09', '2005/08', '2005/07', '2005/06', '2005/05', '2005/04', '2005/03', '2005/02', '2005/01', '2004/12', '2004/11', '2004/10', '2004/09', '2004/08', '2004/07', '2004/06', '2004/05', '2004/04', '2004/03', '2004/02', '2004/01', '2003/12', '2003/11', '2003/10', '2003/09', '2003/08', '2003/07', '2003/06', '2003/05', '2003/04', '2003/03', '2003/02', '2003/01', '2002/12', '2002/11', '2002/10']

# %%
latest_file.replace('\\', "/")
#print(latest_file)
# Out:
# 'C:/Users/Ian/Downloads/02A.xls'

# %%
ruta = '/Users/Juanjo/workspace/j2logo/pruebas.txt'
os.path.split(ruta)
#('/Users/Juanjo/workspace/j2logo', 'pruebas.txt')
# Out:
# ('/Users/Juanjo/workspace/j2logo', 'pruebas.txt')

# %%
print(meses[0].text)
# Out:
# 2021/08
# 2021/07
# 2021/06
# 2021/05
# 2021/04
# 2021/03
# 2021/02
# 2021/01
# 2020/12
# 2020/11
# 2020/10
# 2020/09
# 2020/08
# 2020/07
# 2020/06
